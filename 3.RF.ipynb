# %%
import pandas as pd
dataset=pd.read_csv("CKD.csv")
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent=dataset[['classification_yes']]

# %%
dataset['classification_yes'].value_counts()
# Out:
# 1    249
# 0    150
# Name: classification_yes, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

params_grid={'max_features':['sqrt', 'log2'],'n_estimators': [50, 100, 200],
    'max_depth': [10, 20],'criterion':['gini', 'entropy','log_loss']}

grid=GridSearchCV(RandomForestClassifier(),params_grid,refit=True,scoring='f1',verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\DELL\anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DELL\anaconda3\envs\aiml\lib\site-packages\sklearn\ensemble\_forest.py", line 467, in fit
#     for i, t in enumerate(trees)
# ...

# %%
result=grid.cv_results_
print(result)
# Out:
# {'mean_fit_time': array([0.26239824, 0.39326458, 0.67256269, 0.17891526, 0.33207259,
#        0.85304408, 0.17084284, 0.34549837, 0.6921164 , 0.1857513 ,
#        0.41781521, 0.85366149, 0.17758312, 0.40315824, 0.69913249,
#        0.18397946, 0.35516429, 0.66233859, 0.18078232, 0.33596907,
#        0.67499595, 0.17737603, 0.34179382, 0.6848928 , 0.06561995,
#        0.11683269, 0.22895956, 0.06874433, 0.12441082, 0.21749148,
#        0.07567806, 0.11206226, 0.22327876, 0.06828437, 0.12431283,
#        0.19471903]), 'std_fit_time': array([0.0335848 , 0.03545593, 0.01865333, 0.00787772, 0.01456904,
#        0.09214615, 0.00151801, 0.01152   , 0.01144512, 0.00604877,
#        0.03306661, 0.07115753, 0.00319998, 0.02705293, 0.02061238,
#        0.01012331, 0.00640047, 0.01781508, 0.01085145, 0.00876262,
#        0.01202602, 0.00468401, 0.00591922, 0.04068967, 0.00624919,
#        0.00803455, 0.00986477, 0.00765374, 0.00715096, 0.00859011,
# ...

# %%
y_pred=grid.predict(x_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[44  1]
#  [ 1 74]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        45
#            1       0.99      0.99      0.99        75
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
grid.predict([[12,120,1,100,10,10,120,23,23,3,1,34,21,12,34,0,0,9,0,0,0,0,0,1,1,1,1]])
# Out:
# C:\Users\DELL\anaconda3\envs\aiml\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array([1], dtype=uint8)
